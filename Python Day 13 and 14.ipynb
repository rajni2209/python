# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\Rajnikant Kumar\Downloads\diabetes.csv")  #its to read ccsv file if we want to read excel file read_excel
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df = sns.load_dataset("taxis")

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
sns.barplot(x='payment' , y = 'total',data=df,color='red',estimator = 'mean')
plt.show()
plt.tight_layout()

# %%
sns.histplot(x=df['fare'],color='blue')
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(x=df['fare'],palette=['blue','red'],hue = df['payment'])
plt.show()

# %%
sns.boxplot(x=df['fare'],color='pink')
# Out:
# <Axes: xlabel='fare'>

# %%
iris_data = sns.load_dataset('iris')

# %%
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.boxplot(x=iris_data['sepal_width'],color='orange')
plt.show()

# %%
lower = q1 - 1.5(q3-q1)

upper = q3 + 1.5(q3-q1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 lower = q1 - 1.5(q3-q1)
#       3 upper = q3 + 1.5(q3-q1)
#
# NameError: name 'q1' is not defined

# %%
sns.distplot(x=df['fare'],hist=False,kde = True)
plt.show()

# %%
sns.distplot(x=df['fare'],hist=True,kde = False)
plt.show()

# %%
sns.boxplot(x=iris_data['sepal_width'],palette=['violet','red','lightgreen'],y = iris_data['species'])
plt.show()

# %%
sns.scatterplot(x=df['fare'],y = df['total'],palette=['yellow','red'])
plt.show()

# %%
sns.scatterplot(x=df['fare'],y = df['total'],palette=['yellow','red'],hue=df['payment'])
plt.show()

# %%
sns.stripplot(x=df['fare'],y = df['color'],palette=['yellow','red'])
# Out:
# <Axes: xlabel='fare', ylabel='color'>

# %%
sns.stripplot(x=df['fare'],y = df['payment'],palette=['yellow','red'],hue = df['color'])
# Out:
# <Axes: xlabel='fare', ylabel='payment'>

# %%
sns.swarmplot(x=df['fare'],y = df['payment'],palette=['yellow','red'],hue = df['color'])
# Out:
# <Axes: xlabel='fare', ylabel='payment'>
# Error in callback <function _draw_all_if_interactive at 0x000002020FC58EA0> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:268, in _draw_all_if_interactive()
#     266 def _draw_all_if_interactive() -> None:
#     267     if matplotlib.is_interactive():
# --> 268         draw_all()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backend_bases.py:1905, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1903 if not self._is_idle_drawing:
# ...

# %%
sns.lineplot(x=df['total'],y = df['fare'])
# Out:
# <Axes: xlabel='total', ylabel='fare'>

# %%
sns.lineplot(x=df['total'],y = df['fare'],hue = df['payment'] , palette = ['green','yellow'])
# Out:
# <Axes: xlabel='total', ylabel='fare'>

# %%
sns.countplot(x=df['payment'])
# Out:
# <Axes: xlabel='payment', ylabel='count'>
